# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from os.path import join
import matplotlib.pyplot as plt
from fiona.crs import from_epsg

# %% [markdown]
# # load data

# %% [markdown]
# ### Hamilton County

# %%
nys= gpd.read_file(r"S:\NYState_GIS_DATA\NYS_Civil_Boundaries_SHP\Counties_Shoreline.shp")

# %%
nys.index= nys['NAME']

# %%
nys.loc['Hamilton', 'geometry']

# %%
nys.crs
# Out:
# {'init': 'epsg:26918'}

# %%
nys= nys.to_crs(epsg=4326)

# %%
hamilton= nys.loc['Hamilton', 'geometry']

# %% [markdown]
# ### Buildings

# %%
buildings= gpd.read_file(r"C:\Users\raphael\Desktop\NewYork\NewYork.geojson")

# %%
buildings.crs
# Out:
# {'init': 'epsg:4326'}

# %%
ham_builds= buildings[buildings.within(hamilton)]

# %%
len(ham_builds)
# Out:
# 8979

# %%
len(buildings)
# Out:
# 4844438

# %%
ham_builds.plot()

# %%
ham_builds.to_file(r'C:\Users\raphael\Desktop\NewYork\hamilton_buildings.shp')
# Out:
# C:\Users\raphael\AppData\Local\Continuum\anaconda3\lib\site-packages\geopandas\io\file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():

# %%
ham_builds.to_file(r'C:\Users\raphael\Desktop\NewYork\hamilton_buildings.geojson')
